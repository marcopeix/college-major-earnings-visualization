# %% [markdown]
# # Visualizing Data Based on College Majors
#
# This project analyzes the job outcomes of students who graduated from college between 2010 and 2012. The dataset can be found [here](https://github.com/fivethirtyeight/data/tree/master/college-majors).
#
# Each row represents a different major and contains information on gender diversity, employment rates, median salaries, and more. Here is a description of the dataset:
#
# * `Rank` - Rank by median earnings (dataset is order by this column
# * `Major_code` - A unique code for each major
# * `Major` - Major's description
# * `Major_category` - Category of the major
# * `Total` - Total number of people with this major
# * `Sample_size` - Unweighted sample size of full-time students
# * `Men` - Number of male graduates
# * `Women` - Number of female graduates
# * `Sharewomen` - Share of female graduates
# * `Employed` - Number of employed graduates
# * `Median` - Median salary of full-time workers
# * `Low_wage_jobs` - Graduates in low-wage service jobs
# * `Full_time` - Number of graduates employed 35h or more
# * `Part_time` - Number of graduates employed less than 35h
#
# **Objective**: The objective is to visualize different parts of the data based on the college major.
#
# **Techniques used:**
# * Pandas, Numpy, Matplotlib
# * Scatter plot, histograms, bar plots, scatter matrix plots
# * Grouped bar plot
# * Box plot
# * Hexagonal bin plot

# %% [markdown]
# ## Dataset Introduction

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

recent_grads = pd.read_csv('recent-grads.csv')

recent_grads.iloc[0]

print(recent_grads.head())
print(recent_grads.tail())

recent_grads.describe()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %% [markdown]
# ## Remove columns with missing values

# %%
recent_grads = recent_grads.dropna()

# %% [markdown]
# ## Correlating sample size and median salary with scatter plots

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %% [markdown]
# From the plot above, it is seen that there is no strong correlation between the sample size and the median salary.

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# Again, the correlation is very weak between sample size and unemployment rate.

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter')

# %% [markdown]
# Once more, no strong correlation can be drawn from the plot above. Therefore, working full-time does not seem to have a direct correlation with the median salary.

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# As observed, there is no strong correlation between the share of women in a major and the unemployment rate. Therefore, the two variables do not impact each other.

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %% [markdown]
# From the plot, the number of men who graduated from a certain major does not correlate with the median salary of its graduates.

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %% [markdown]
# Again, the number of women does not seem to impact the median salary.

# %% [markdown]
# ## Exploring different data distribution with histograms

# %%
cols = ['Sample_size', 'Median', 'Employed', 'Full_time', 'ShareWomen', 'Unemployment_rate', 'Men', 'Women']

fig = plt.figure(figsize=(5,15))

for i in range(0,8):
    ax = fig.add_subplot(8,1,i+1)
    ax = recent_grads[cols[i]].plot(kind='hist', rot=40, title=cols[i])

# %% [markdown]
# From the histograms above, the most popular sample size seems to be 0. A median salary of $30,000 is the most frequent and and most graduates are not employed. This explains why a lot of graduates are not employed full-time, and why the unemployment rate is fairly high. Finally, the distribution of men and women across major is fairly bad, meaning that some majors have a high male population with low female population, and vice versa.

# %% [markdown]
# ## Visualizing with scatter matrix plots

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f02fe4212b0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f02fe0850b8>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f02fe10ca20>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f02fc4f30b8>]], dtype=object)

# %% [markdown]
# ## Visualizing with bar plots

# %%
recent_grads[:10].plot.bar(x = 'Major', y = 'ShareWomen')

# %%
recent_grads[-10:].plot.bar(x = 'Major', y = 'ShareWomen')

# %% [markdown]
# As observed, the share of women is much higher in low-paying majors than in high-paying  majors.

# %%
recent_grads[:10].plot.bar(x = 'Major', y = 'Unemployment_rate')

# %%
recent_grads[-10:].plot.bar(x = 'Major', y = 'Unemployment_rate')

# %% [markdown]
# ## Visualizing male and female graduates in each major

# %%
import numpy as np

tbl = recent_grads.pivot_table(index='Major_category', values = ['Men', 'Women'], aggfunc=np.sum)
tbl.plot.bar(x = tbl.index, y = ['Men', 'Women'])

# %% [markdown]
# As observed, women are mostly present in the fields of education, liberal arts, psychology and social work, whereas men dominate the field of engineering. Interestingly, in the field of business, both men and women are almost equally present.

# %% [markdown]
# ## Visualizing the distribution of median salaries

# %%
recent_grads['Median'].plot(kind='box')

# %% [markdown]
# As observed, more than 50% of the median salaries reported are above 35 000 USD and go as high as 60 000 USD.

# %% [markdown]
# ## Visualizing median salary and full-time employment using a hexagonal bin plot

# %%
recent_grads.plot.hexbin(x = 'Full_time', y = '')
